# %% [markdown]
# **Assignment_1**

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Load in the appropriate csv file as a pandas dataframe (batting.csv)**

# %%
batting_data = pd.read_csv('Batting.csv')

# %%
batting_data.head()
# Out:
#     playerID nameFirst     nameLast  birthYear  yearID  stint teamID lgID   G  \
# 0  abercda01     Frank  Abercrombie       1850    1871      1    TRO  NaN   1
# 1   addybo01       Bob         Addy       1842    1871      1    RC1  NaN  25
# 2  allisar01       Art      Allison       1849    1871      1    CL1  NaN  29
# 3  allisdo01      Doug      Allison       1846    1871      1    WS3  NaN  27
# 4  ansonca01       Cap        Anson       1852    1871      1    RC1  NaN  25
#
#     AB  ...    RBI   SB   CS  BB   SO  IBB  HBP  SH  SF  GIDP
# 0    4  ...    0.0  0.0  0.0   0  0.0  NaN  NaN NaN NaN   NaN
# 1  118  ...   13.0  8.0  1.0   4  0.0  NaN  NaN NaN NaN   NaN
# 2  137  ...   19.0  3.0  1.0   2  5.0  NaN  NaN NaN NaN   NaN
# 3  133  ...   27.0  1.0  1.0   0  2.0  NaN  NaN NaN NaN   NaN
# 4  120  ...   16.0  6.0  2.0   2  1.0  NaN  NaN NaN NaN   NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ** print out the dimensions and info about the data you just created **

# %%
print(batting_data.shape)
# Out:
# (102816, 25)

# %%
print(batting_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102816 entries, 0 to 102815
# Data columns (total 25 columns):
# playerID     102816 non-null object
# nameFirst    102816 non-null object
# nameLast     102816 non-null object
# birthYear    102816 non-null int64
# yearID       102816 non-null int64
# stint        102816 non-null int64
# teamID       102816 non-null object
# lgID         102079 non-null object
# G            102816 non-null int64
# AB           102816 non-null int64
# R            102816 non-null int64
# H            102816 non-null int64
# 2B           102816 non-null int64
# 3B           102816 non-null int64
# HR           102816 non-null int64
# RBI          102392 non-null float64
# SB           101516 non-null float64
# CS           79360 non-null float64
# BB           102816 non-null int64
# SO           94978 non-null float64
# IBB          66251 non-null float64
# HBP          100006 non-null float64
# SH           96478 non-null float64
# ...

# %% [markdown]
# **3)How many players have hit 40 or more HRs in one single season? (Number only)**

# %%
#select players by aggregation
a3 = batting_data.groupby(["playerID","yearID"], as_index = False)['HR'].sum()
print(a3[a3['HR']>=40]['playerID'].nunique())
# Out:
# 142

# %% [markdown]
# **4)How many players have hit 600  or more HRs for their career? (Dataframe with name and player first name and last name only and amount of HRs)**

# %%
#select players by aggregation
a4 = batting_data.groupby(["playerID","nameFirst","nameLast"], as_index = False)['HR'].sum()
display(a4[a4['HR']>=600][['playerID','nameFirst', 'nameLast','HR']].reset_index(drop=True))
# Out:
#     playerID nameFirst   nameLast   HR
# 0  aaronha01      Hank      Aaron  755
# 1  bondsba01     Barry      Bonds  762
# 2  griffke02       Ken    Griffey  630
# 3   mayswi01    Willie       Mays  660
# 4  rodrial01      Alex  Rodriguez  696
# 5   ruthba01      Babe       Ruth  714
# 6   sosasa01     Sammy       Sosa  609
# 7  thomeji01       Jim      Thome  612

# %% [markdown]
# **5)How many players have hit 40 2Bs, 10 3Bs, 200 Hits, and 30 HRs (inclusive) in one season? (Number Only, unique)**

# %%
#select players by aggregation
a5 = batting_data.groupby(["playerID","yearID"], as_index = False)['2B','3B','H','HR'].sum()
print(a5[(a5['2B']>=40) & (a5['3B']>=10) & (a5['H']>=200) & (a5['HR']>=30)]['playerID'].nunique())
# Out:
# 11

# %% [markdown]
# **6)How many players seasons have had 100 or more SBs in a season? (Dataframe, first name, last name, number of SBs, ordered from descending SBs)**

# %%
#select players by aggregation
a6 = batting_data.groupby(["playerID","nameFirst","nameLast","yearID"], as_index = False)['SB'].sum()
a6.sort_values('SB',inplace=True,ascending=False)
display(a6[a6['SB'] >= 100][['playerID','nameFirst','nameLast','SB']].reset_index(drop=True).drop_duplicates('playerID').reset_index(drop=True))
# Out:
#      playerID nameFirst   nameLast     SB
# 0   nicolhu01      Hugh      Nicol  138.0
# 1   henderi01    Rickey  Henderson  130.0
# 2   lathaar01     Arlie     Latham  129.0
# 3   brocklo01       Lou      Brock  118.0
# 4   comisch01   Charlie   Comiskey  117.0
# 5   hamilbi01     Billy   Hamilton  111.0
# 6    wardjo01      John       Ward  111.0
# 7   colemvi01     Vince    Coleman  110.0
# 8   brownto01       Tom      Brown  106.0
# 9   willsma01     Maury      Wills  104.0
# 10  brownpe01      Pete   Browning  103.0
# 11  fogarji01       Jim    Fogarty  102.0

# %% [markdown]
# **7)How many players in the 1960s (yearID) have hit  200 or more HRs? (Dataframe, firstname, lastname, number of HRs, ordered descending by HR amt)**

# %%
new_batting=batting_data[(batting_data['yearID'] >= 1960) & (batting_data['yearID'] < 1970)]
new_bat=new_batting.groupby(['playerID','nameFirst','nameLast'],as_index=False)[['HR']].sum()
new_bat[new_bat['HR']>=200][['nameFirst','nameLast','HR']].sort_values(by='HR',ascending=False)
# Out:
#      nameFirst     nameLast   HR
# 856     Harmon    Killebrew  393
# 0         Hank        Aaron  375
# 1044    Willie         Mays  350
# 1372     Frank     Robinson  316
# 1057    Willie      McCovey  300
# 751      Frank       Howard  288
# 279       Norm         Cash  278
# 70       Ernie        Banks  269
# 1009    Mickey       Mantle  256
# 283    Orlando       Cepeda  254
# 1428       Ron        Santo  253
# 1730     Billy     Williams  249
# 323      Rocky     Colavito  245
# 19         Bob      Allison  225
# 1014     Roger        Maris  217
# 1031     Eddie      Mathews  213
# 830         Al       Kaline  210
# 1296      Boog       Powell  202
# 1775      Carl  Yastrzemski  202

# %% [markdown]
# **8)Who has hit the most HRs in history? (Dataframe, First name, last name, HRs)**

# %%
#Aggregate the data based on playerID
a8 = batting_data.groupby(["playerID","nameFirst","nameLast"], as_index = False)['HR'].sum()
#Display
display(a8[a8['HR'] == (a8['HR'].max())].reset_index(drop = True))
# Out:
#     playerID nameFirst nameLast   HR
# 0  bondsba01     Barry    Bonds  762

# %% [markdown]
# **9)Who had the most hits(H) in the 1970s? (Dataframe)**

# %%
a9 = batting_data[(batting_data['yearID'] >=1970) & (batting_data['yearID'] <1980)][['playerID','nameFirst','nameLast','H']].reset_index(drop=True)
a90 = a9.groupby(["playerID","nameFirst","nameLast"], as_index = False)['H'].sum()
display(a90[a90['H'] == (a90['H'].max())].reset_index(drop = True))
# Out:
#    playerID nameFirst nameLast     H
# 0  rosepe01      Pete     Rose  2045

# %% [markdown]
# **10)Top 5 highest OBP (on base percentage) with at least 500 PAs in 1977?  (Dataframe, first name, last name, OBP, order descending by OBP)**

# %%
#Select data for 1977
a10 = batting_data[batting_data['yearID']==1977].reset_index(drop=True)

#Aggregate based on playerID
a100 = a10.groupby(["playerID", "nameFirst", "nameLast"],as_index=False)[['AB','BB','HBP','SH','SF','H']].sum()

#Calculate the PA
a100['PA'] = a100['AB'] + a100['BB'] + a100['HBP'] + a100['SH'] + a100['SF']

#Selecting players with PA greater than or equal to 500
pa10 = a100[a100['PA']>=500].reset_index(drop=True)

#Calculating OBP
pa10['OBP'] = ( pa10['H'] + pa10['BB'] + pa10['HBP'])/(pa10['AB']+ pa10['BB'] + pa10['HBP'] +pa10['SF'])

#Sort the values
pa10.sort_values('OBP',inplace=True,ascending=False)
#display
display(pa10.head(5).reset_index(drop=True))
# Out:
#     playerID nameFirst   nameLast   AB   BB  HBP   SH   SF    H     PA  \
# 0  carewro01       Rod      Carew  616   69  3.0  1.0  5.0  239  694.0
# 1  singlke01       Ken  Singleton  536  107  2.0  0.0  6.0  176  651.0
# 2  smithre06    Reggie      Smith  488  104  3.0  1.0  7.0  150  603.0
# 3  hargrmi01      Mike   Hargrove  525  103  6.0  8.0  6.0  160  648.0
# 4  morgajo02       Joe     Morgan  521  117  2.0  0.0  5.0  150  645.0
#
#         OBP
# 0  0.448773
# 1  0.437788
# 2  0.426910
# 3  0.420312
# 4  0.417054

# %% [markdown]
# **11)Top 8 highest averages in 2013 with at least 300 PAs? (Dataframe, first name, last name and descending by average)**

# %%
#Select data of 2013 
a11 = batting_data[batting_data['yearID']==2013].reset_index(drop = True)
a111 = a11[a11['AB']!=0].copy()
#Calculate PA greater than or equal to 300
a111 = a111.groupby(["yearID","nameFirst","nameLast"], as_index = False)[['AB','BB','HBP','SH','SF','H']].sum()
a111['PA'] = a111['AB'] + a111['BB'] + a111['HBP'] + a111['SH'] + a111['SF']
pa11 = a111[a111['PA'] >= 300].copy()
#Calculate average
pa11['AVG'] = pa11['H']/pa11['AB']
pa11.sort_values('AVG', inplace = True, ascending = False)
display(pa11.head(8).reset_index(drop = True))
# Out:
#    yearID nameFirst nameLast   AB   BB   HBP   SH   SF    H     PA       AVG
# 0    2013    Miguel  Cabrera  555   90   5.0  0.0  2.0  193  652.0  0.347748
# 1    2013    Hanley  Ramirez  304   27   3.0  0.0  2.0  105  336.0  0.345395
# 2    2013   Michael  Cuddyer  489   46   2.0  0.0  3.0  162  540.0  0.331288
# 3    2013       Joe    Mauer  445   61   0.0  0.0  2.0  144  508.0  0.323596
# 4    2013      Mike    Trout  589  110   9.0  0.0  8.0  190  716.0  0.322581
# 5    2013     Chris  Johnson  514   29   2.0  0.0  2.0  165  547.0  0.321012
# 6    2013   Freddie  Freeman  551   66   7.0  0.0  5.0  176  629.0  0.319419
# 7    2013    Yasiel     Puig  382   36  11.0  0.0  3.0  122  432.0  0.319372

# %% [markdown]
# **12)Leaders in hits from 1940 up to and including 1949. (Dataframe, first name, last name, number of hits)**

# %%
#Extract data between 1940 and 1949
a12 = batting_data[(batting_data['yearID'] >= 1940) & (batting_data['yearID'] < 1950)].copy()
#Aggregating
a122 = a12.groupby(["nameFirst","nameLast"], as_index = False).sum()
a122.sort_values('H',inplace = True, ascending = False)
display(a122[['nameFirst','nameLast','H']].head(100).reset_index(drop=True))
# Out:
#    nameFirst    nameLast     H
# 0        Lou    Boudreau  1578
# 1        Bob     Elliott  1563
# 2      Dixie      Walker  1512
# 3       Stan      Musial  1432
# 4      Bobby       Doerr  1407
# 5      Tommy      Holmes  1402
# 6       Luke     Appling  1376
# 7       Bill   Nicholson  1328
# 8      Marty      Marion  1310
# 9       Phil  Cavarretta  1304
# 10       Ted    Williams  1303
# 11      Vern    Stephens  1290
# 12      Rudy        York  1266
# 13     Frank   McCormick  1261
# 14       Ken     Keltner  1211
# 15     Wally       Moses  1205
# 16   Frankie     Gustine  1198
# 17      Enos   Slaughter  1190
# 18    George     McQuinn  1171
# 19       Joe      Gordon  1165
# 20       Joe    DiMaggio  1156
# 21      Stan        Hack  1155
# 22       Dom    DiMaggio  1154
# 23    Mickey      Vernon  1149
# 24       Doc      Cramer  1148
# 25     Eddie      Miller  1142
# 26      Jeff       Heath  1121
# 27    Johnny        Hopp  1116
# 28    George        Case  1097
# ...

# %% [markdown]
# **13)	Who led MLB with the most hits the most times?  And how many times?  (Dataframe, Number of hits)**

# %%
#Aggregate with Player and Year
a13 = batting_data.groupby(['playerID','yearID'],as_index=False)[['H']].sum().copy()
a133 = a13.groupby('yearID',as_index=False)[['H']].max().copy()
a13_merged = pd.merge(a133,a13,how='left',on=['yearID','H']).copy()
#Find the number of times each player scored the most hits in a year
a13_merged['Number_of_Times']=a13_merged.groupby('playerID',as_index=False)['yearID'].count()['yearID']
a13_merged.sort_values('Number_of_Times',inplace=True,ascending=False)
#Displaying the result
display(a13_merged.reset_index(drop=True).head(1))
# Out:
#    yearID    H  playerID  Number_of_Times
# 0    1950  218  kellge01              7.0

# %% [markdown]
# **14)Which players have played the most games for their careers?  Top 5, descending by games played presented as a dataframe**

# %%
a14 = batting_data.groupby(["playerID","nameFirst","nameLast"], as_index = False).sum().copy()
a14.sort_values('G', inplace = True, ascending = False)
display(a14.loc[:,['playerID','nameFirst','nameLast','G']].head(5).reset_index(drop = True))
# Out:
#     playerID nameFirst     nameLast     G
# 0   rosepe01      Pete         Rose  3562
# 1  yastrca01      Carl  Yastrzemski  3308
# 2  aaronha01      Hank        Aaron  3298
# 3  henderi01    Rickey    Henderson  3081
# 4   cobbty01        Ty         Cobb  3035

# %% [markdown]
# **15)How many players have had more than 3000 hits for their careers while also hitting 500 or more HRs?  Just a number is okay here**

# %%
a15 = batting_data.groupby('playerID', as_index = False).sum().copy()
print(len(a15[(a15['H'] > 3000 ) & (a15['HR'] > 500)].index))
# Out:
# 5

# %% [markdown]
# **16)How many HRs were hit during the entire 1988 season?  Just a number is okay here**

# %%
a16 = batting_data.groupby('yearID', as_index = False)['HR'].sum().copy()
print(a16[a16['yearID'] == 1988]['HR'].item())
# Out:
# 3180

# %% [markdown]
# **17. Please filter out and show me the top 3 average seasons by Wade Boggs during his career in seasons in which he had at least 500 or more ABs.  Data frame, first name, last name, average, descending by average**

# %%
a17 = batting_data[(batting_data['nameFirst'] == 'Wade') & (batting_data['nameLast'] == 'Boggs')].copy()
#Filtering the data
a17_Filtered = a17[a17['AB'] >= 500].copy()
#Calculating Average
a17_Filtered['Average'] = (a17_Filtered['H']/a17_Filtered['AB'])
a17_Filtered.sort_values('Average', inplace = True, ascending = False)
display(a17_Filtered.head(3))
# Out:
#         playerID nameFirst nameLast  birthYear  yearID  stint teamID lgID  \
# 62316  boggswa01      Wade    Boggs       1958    1985      1    BOS   AL
# 65391  boggswa01      Wade    Boggs       1958    1988      1    BOS   AL
# 64335  boggswa01      Wade    Boggs       1958    1987      1    BOS   AL
#
#          G   AB    ...      SB   CS   BB    SO   IBB  HBP   SH   SF  GIDP  \
# 62316  161  653    ...     2.0  1.0   96  61.0   5.0  4.0  3.0  2.0  20.0
# 65391  155  584    ...     2.0  3.0  125  34.0  18.0  3.0  0.0  7.0  23.0
# 64335  147  551    ...     1.0  3.0  105  48.0  19.0  2.0  1.0  8.0  13.0
#
#         Average
# 62316  0.367534
# 65391  0.366438
# 64335  0.362976
#
# [3 rows x 26 columns]

# %% [markdown]
# **18)Please filter out the top 10 OBPs for the 1995 season with 400 or more PAs, sorted by OBP descending.  Dataframe with first name, last name, OBP**

# %%
a18 = batting_data[batting_data['yearID'] == 1995].reset_index(drop = True)
#Aggregate
a188_non_zero = a18.groupby(['playerID','nameFirst','nameLast'], as_index = False)[['AB','BB','HBP','SH','SF','H']].sum()
#PA>400
a188_non_zero['PA'] = a188_non_zero['AB'] + a188_non_zero['BB'] + a188_non_zero['HBP'] + a188_non_zero['SH'] + a188_non_zero['SF']
pa = a188_non_zero[a188_non_zero['PA'] > 400].copy()
#OBP
pa['OBP'] = (pa['H'] + pa['BB'] + pa['HBP'])/(pa['AB'] + pa['BB'] + pa['HBP'] + pa['SF'])
pa.sort_values('OBP', inplace = True, ascending = False)
display(pa.reset_index(drop = True).head(10))
# Out:
#     playerID nameFirst   nameLast   AB   BB   HBP   SH    SF    H     PA  \
# 0  martied01     Edgar   Martinez  511  116   8.0  0.0   4.0  182  639.0
# 1  thomafr04     Frank     Thomas  493  136   6.0  0.0  12.0  152  647.0
# 2  mcgwima01      Mark    McGwire  317   88  11.0  0.0   6.0   87  422.0
# 3  thomeji01       Jim      Thome  452   97   5.0  0.0   3.0  142  557.0
# 4  bondsba01     Barry      Bonds  506  120   5.0  0.0   4.0  149  635.0
# 5  salmoti01       Tim     Salmon  537   91   6.0  0.0   4.0  177  638.0
# 6  davisch01     Chili      Davis  424   89   0.0  0.0   9.0  135  522.0
# 7  magadda01      Dave    Magadan  348   71   0.0  1.0   2.0  109  422.0
# 8  knoblch01     Chuck  Knoblauch  538   78  10.0  0.0   3.0  179  629.0
# 9  naehrti01       Tim   Naehring  433   77   4.0  4.0   2.0  133  520.0
#
#         OBP
# 0  0.478873
# 1  0.454405
# 2  0.440758
# 3  0.438061
# 4  0.431496
# 5  0.429467
# 6  0.429119
# 7  0.427553
# 8  0.424483
# 9  0.414729

# %% [markdown]
# **19)Who had the most 3Bs (in total) in 1922, 1925, 1926, and 1928?  I would like a dataframe with first name, last name, number of 3Bs**

# %%
a19 = batting_data[(batting_data['yearID'] ==1922)|(batting_data['yearID'] == 1925)|(batting_data['yearID']==1926)|(batting_data['yearID']==1928)].reset_index(drop = True)
a199 = a19.groupby(['playerID','nameFirst', 'nameLast'], as_index = False).sum()
display(a199[a199['3B'] == a199['3B'].max()][['playerID', 'nameFirst', 'nameLast', '3B']].reset_index(drop = True))
# Out:
#     playerID nameFirst nameLast  3B
# 0  walkecu01      Curt   Walker  59

# %% [markdown]
# **20)How many unique players have hit 30 or more HRs in season while also stealing (SB) 30 more or bases?  A number is okay here**

# %%
a20 = batting_data.groupby(['playerID','yearID'], as_index = False).sum().copy()
a200 = a20[a20['HR'] >= 30]
print(a200[a200['SB']>=30]['playerID'].nunique())
# Out:
# 38

# %% [markdown]
# **21)Who had the highest OBP is 1986 with 400 or more ABs? (Dataframe first name, last name, OBP)**

# %%
a21 = batting_data[batting_data['yearID']==1986].reset_index(drop=True)
a211 = a21.groupby(['playerID','nameFirst','nameLast'],as_index=False).sum()
#Calculate PA
a211['PA'] = a211['AB'] + a211['BB'] + a211['HBP'] + a211['SH'] + a211['SF']
#Selecting players with PA>=400
pa21 = a211[a211['PA']>=400].copy()
#Calculating OBP
pa21['OBP'] = (pa21['H'] + pa21['BB'] + pa21['HBP'])/(pa21['AB'] + pa21['BB'] + pa21['HBP'] + pa21['SF'])
#Display
display(pa21[pa21['OBP'] == pa21['OBP'].max()].reset_index(drop=True))
# Out:
#     playerID nameFirst nameLast  birthYear  yearID  stint    G   AB    R    H  \
# 0  boggswa01      Wade    Boggs       1958    1986      1  149  580  107  207
#
#     ...      CS   BB    SO   IBB  HBP   SH   SF  GIDP     PA      OBP
# 0   ...     4.0  105  44.0  14.0  0.0  4.0  4.0  11.0  693.0  0.45283
#
# [1 rows x 25 columns]

# %% [markdown]
# **22)Same question but for 1997 and only in the NL (check league ID)? (Dataframe, first name, last name OBP)**

# %%
a22 = batting_data[batting_data['yearID']==1997].reset_index(drop=True)
#Selecting Players in NL 
a222 = a22[a22['lgID']=='NL']
#Aggregating 
a2222 = a22.groupby('playerID',as_index=False).sum()
#Calculating PA
a2222['PA'] = a2222['AB'] + a2222['BB'] + a2222['HBP'] + a2222['SH'] + a2222['SF']
# PA >= 400
pa22 = a2222[a2222['PA']>=400].copy()
#Calculating OBP
pa22['OBP'] = (pa22['H'] + pa22['BB'] + pa22['HBP'])/(pa22['AB'] + pa22['BB'] + pa22['HBP'] + pa22['SF'])
#Displaying the Player with the highest OBP
display(pa22[pa22['OBP'] == pa22['OBP'].max()].reset_index(drop=True))
# Out:
#     playerID  birthYear  yearID  stint    G   AB    R    H  2B  3B    ...     \
# 0  thomafr04       1968    1997      1  146  530  110  184  35   0    ...
#
#     CS   BB    SO  IBB  HBP   SH   SF  GIDP     PA       OBP
# 0  1.0  109  69.0  9.0  3.0  0.0  7.0  15.0  649.0  0.456086
#
# [1 rows x 23 columns]

# %% [markdown]
# **23)Who had more than the league average HRs (for players with 500 or more ABs) in 2012 (filter out all players with less 500 ABs)? (Dataframe first name, last name, HR descending)**

# %%
a23 = batting_data[batting_data['yearID']==2012]
a233=a23[a23['AB']>=500]
a233[a233['HR']>a233['HR'].mean()] 
a23_3=a233[a233['HR']>a233['HR'].mean()]
a23_3[['nameFirst','nameLast','HR']].sort_values(by='HR',ascending=False)
# Out:
#       nameFirst     nameLast  HR
# 95768    Miguel      Cabrera  44
# 96114      Josh     Hamilton  43
# 96081    Curtis   Granderson  43
# 95969     Edwin  Encarnacion  42
# 95728      Ryan        Braun  41
# 95952      Adam         Dunn  41
# 95687    Adrian       Beltre  36
# 96971      Josh   Willingham  35
# 95741       Jay        Bruce  34
# 96301      Adam      LaRoche  33
# 95777  Robinson         Cano  33
# 95894     Chris        Davis  33
# 96248      Adam        Jones  32
# 96890      Mark       Trumbo  32
# 95895       Ike        Davis  32
# 96663      Josh      Reddick  32
# 95688    Carlos      Beltran  32
# 96812   Alfonso      Soriano  32
# 96138     Chase      Headley  31
# 96425    Andrew    McCutchen  31
# 95619     Pedro      Alvarez  30
# 96628    Albert       Pujols  30
# 95993    Prince      Fielder  30
# 96133     Corey         Hart  30
# 96889      Mike        Trout  30
# 96291     Jason        Kubel  30
# 95759     Billy       Butler  29
# ...

# %% [markdown]
# **24)Who is the youngest player to hit 50 or more HRs in a single season? (Dataframe, first name, last name, HRs, season)**

# %%
#Aggregating
a24 = batting_data.groupby(['playerID','yearID','birthYear','nameFirst','nameLast'],as_index=False).sum().copy()
#Selecting players with HR greater than or equal to 50
hr = a24[a24['HR']>=50].copy()
#Calculating approximate age 
hr['Req_Age'] = hr['yearID'] - hr['birthYear']
#Displaying the youngest player to hit 50 or more HRs
display(hr[hr['Req_Age']== (hr['Req_Age'].min())][['playerID','nameFirst','nameLast','yearID','birthYear','HR','Req_Age']].reset_index(drop=True))
# Out:
#     playerID nameFirst nameLast  yearID  birthYear  HR  Req_Age
# 0  fieldpr01    Prince  Fielder    2007       1984  50       23

# %% [markdown]
# **25)Who are the five youngest players to hit 300 or more HRs for their career? (Dataframe, first name, last name, season they eclipsed more than 300 HRs)**

# %%
a25 = batting_data.groupby(['playerID', 'nameFirst', 'nameLast', 'birthYear', 'yearID']).sum().groupby(level=0).cumsum().reset_index().copy()
#Sorting
a25 = a25[a25['HR'] >= 300].sort_values(by = ['yearID', 'birthYear', 'playerID'])[['playerID', 'nameFirst', 'nameLast', 'birthYear', 'yearID', 'HR']]
#Finding the required age
a25['Req_Age'] = a25['yearID'] - a25['birthYear']
#Displaying the five youngest players to hit 300 or more HRs
display(a25.sort_values(by = 'Req_Age', ascending = True).head(5).reset_index(drop=True))
# Out:
#     playerID nameFirst   nameLast  birthYear  yearID   HR  Req_Age
# 0  pujolal01    Albert     Pujols       1980    2008  319       28
# 1    ottme01       Mel        Ott       1909    1937  306       28
# 2  jonesan01    Andruw      Jones       1977    2005  301       28
# 3   foxxji01    Jimmie       Foxx       1907    1935  302       28
# 4  rodrial01      Alex  Rodriguez       1975    2003  345       28

# %% [markdown]
# **BONUS QUESTION**

# %% [markdown]
# **Importing Libraries:**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Aggregate
bonus = batting_data.groupby('yearID',as_index=False).sum().copy()
bonus['HR']
# Out:
# 0        47
# 1        35
# 2        46
# 3        40
# 4        40
# 5        40
# 6        24
# 7        23
# 8        58
# 9        62
# 10       76
# 11      178
# 12      238
# 13      690
# 14      323
# 15      413
# 16      606
# 17      521
# 18      667
# 19      760
# 20      586
# 21      417
# 22      460
# 23      627
# 24      484
# 25      404
# 26      367
# 27      299
# 28      350
# 29      254
#        ...
# 116    4458
# 117    3180
# 118    3083
# 119    3317
# 120    3383
# 121    3038
# 122    4030
# 123    3306
# 124    4081
# 125    4962
# 126    4640
# 127    5064
# 128    5528
# 129    5693
# 130    5458
# 131    5059
# 132    5207
# 133    5451
# 134    5017
# 135    5386
# 136    4957
# 137    4878
# 138    5042
# 139    4613
# 140    4552
# 141    4934
# 142    4661
# 143    4186
# 144    4909
# 145    5610
# Name: HR, Length: 146, dtype: int64

# %%
fig = plt.figure()
# Add set_of_axes
axes = fig.add_axes([0.5, 0.5, 2.5, 1.5])
#Ploting the total HRs per season using bar graph
axes.bar(bonus['yearID'], bonus['HR'], align='center', alpha=1.0)
axes.set_ylabel('Number of Home Runs')
axes.set_xlabel('Year')
axes.set_title('Total HRs per Season')
# Out:
# Text(0.5,1,'Total HRs per Season')

# %% [markdown]
# **Using a line graph please graph the average HRs per AB (think about this) per season**

# %%
#Aggregate
bonus = batting_data.groupby('yearID',as_index=False).mean().copy()
bonus['Req_Avg'] = bonus['HR']/bonus['AB']

fig = plt.figure()
# Add set_of_axes
axes = fig.add_axes([0.5, 0.5, 2.5, 1.5])
axes.plot(bonus['yearID'], bonus['Req_Avg'])
axes.set_ylabel('Average Home Runs per AB')
axes.set_xlabel('Year')
axes.set_title('Average HRs per AB per Season')
# Out:
# Text(0.5,1,'Average HRs per AB per Season')
